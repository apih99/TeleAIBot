# %%
import asyncio
from telegram import Update
from telegram.ext import ApplicationBuilder, CommandHandler, MessageHandler, filters, ContextTypes
import google.generativeai as genai
import nest_asyncio

# Telegram bot token (replace with your actual token)
TOKEN = '7642503905:AAGcLYCNxemrTamAsAITI0P2B4YZ4m5sCCk'
API_KEY = 'AIzaSyB97LqFGkQKMtpYomR644c42XVrjTFKo9s'

# Configure the generative model
genai.configure(api_key=API_KEY)
model = genai.GenerativeModel('gemini-2.0-flash-exp')

def generate_content(full_prompt: str) -> str:
    try:
        response = model.generate_content(full_prompt)
        return response.text if hasattr(response, 'text') else "Sorry, I couldn't generate a response."
    except Exception as e:
        return f"There was an error generating the response: {str(e)}"

async def start(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    user_id = update.effective_user.first_name
    system_message = f"Hello {user_id}! I am a chatbot. How can I help you today?"
    await update.message.reply_text(system_message)

async def chat(update: Update, context: ContextTypes.DEFAULT_TYPE) -> None:
    user_message = update.message.text
    response_text = generate_content(user_message)
    await update.message.reply_text(response_text)

async def main() -> None:
    # Build the application
    app = ApplicationBuilder().token(TOKEN).build()

    # Add handlers
    app.add_handler(CommandHandler("start", start))
    app.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, chat))

    # Run the bot
    try:
        await app.run_polling()
    finally:
        if hasattr(app, "shutdown") and callable(app.shutdown): # Added conditional check to avoid errors
          await app.shutdown()

if __name__ == '__main__':
    nest_asyncio.apply()
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telegram\ext\_application.py:1069, in Application.__run(self, updater_coroutine, stop_signals, close_loop)
#    1068 try:
# -> 1069     loop.run_until_complete(self.initialize())
#    1070     if self.post_init:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\futures.py:203, in Future.result(self)
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# ...
